# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 726

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | nikolskoye
# Processing Record 4 of Set 1 | vao
# Processing Record 5 of Set 1 | baruun-urt
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 1 | chokurdakh
# Processing Record 9 of Set 1 | artyk
# City not found. Skipping...
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | jaru
# Processing Record 12 of Set 1 | ust-nera
# Processing Record 13 of Set 1 | kodiak
# Processing Record 14 of Set 1 | grindavik
# Processing Record 15 of Set 1 | riga
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | east london
# Processing Record 19 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 1 | voh
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | saint-philippe
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 1 | obo
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | macaboboni
# City not found. Skipping...
# Processing Record 28 of Set 1 | kavieng
# Processing Record 29 of Set 1 | qaanaaq
# Processing Record 30 of Set 1 | flin flon
# Processing Record 31 of Set 1 | port alfred
# Processing Record 32 of Set 1 | deputatskiy
# Processing Record 33 of Set 1 | saint-georges
# Processing Record 34 of Set 1 | castro
# Processing Record 35 of Set 1 | komsomolskiy
# Processing Record 36 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 1 | aripuana
# Processing Record 38 of Set 1 | jonacatepec
# Processing Record 39 of Set 1 | katsuura
# Processing Record 40 of Set 1 | talcahuano
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | masyaf
# Processing Record 43 of Set 1 | mandalgovi
# Processing Record 44 of Set 1 | isangel
# Processing Record 45 of Set 1 | hermanus
# Processing Record 46 of Set 1 | georgetown
# Processing Record 47 of Set 1 | puerto ayora
# Processing Record 48 of Set 1 | tadine
# Processing Record 49 of Set 1 | nelson
# Processing Record 50 of Set 1 | kondagaon
# Processing Record 1 of Set 2 | ushuaia
# Processing Record 2 of Set 2 | richards bay
# Processing Record 3 of Set 2 | morant bay
# Processing Record 4 of Set 2 | caravelas
# Processing Record 5 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 2 | banda aceh
# Processing Record 8 of Set 2 | bethel
# Processing Record 9 of Set 2 | luderitz
# Processing Record 10 of Set 2 | noyabrsk
# Processing Record 11 of Set 2 | saskylakh
# Processing Record 12 of Set 2 | albany
# Processing Record 13 of Set 2 | arraial do cabo
# Processing Record 14 of Set 2 | belmonte
# Processing Record 15 of Set 2 | tiksi
# Processing Record 16 of Set 2 | monteagudo
# Processing Record 17 of Set 2 | alice springs
# Processing Record 18 of Set 2 | saint-junien
# Processing Record 19 of Set 2 | tuktoyaktuk
# Processing Record 20 of Set 2 | pevek
# Processing Record 21 of Set 2 | kabanjahe
# Processing Record 22 of Set 2 | torbay
# Processing Record 23 of Set 2 | ibra
# Processing Record 24 of Set 2 | leningradskiy
# Processing Record 25 of Set 2 | port-gentil
# Processing Record 26 of Set 2 | garissa
# Processing Record 27 of Set 2 | sao filipe
# Processing Record 28 of Set 2 | nome
# Processing Record 29 of Set 2 | nantucket
# Processing Record 30 of Set 2 | shache
# Processing Record 31 of Set 2 | lompoc
# Processing Record 32 of Set 2 | cape town
# Processing Record 33 of Set 2 | yellowknife
# Processing Record 34 of Set 2 | khatanga
# Processing Record 35 of Set 2 | klaksvik
# Processing Record 36 of Set 2 | upernavik
# Processing Record 37 of Set 2 | vila velha
# Processing Record 38 of Set 2 | domoni
# Processing Record 39 of Set 2 | churapcha
# Processing Record 40 of Set 2 | port elizabeth
# Processing Record 41 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 42 of Set 2 | nemuro
# Processing Record 43 of Set 2 | airai
# Processing Record 44 of Set 2 | nanlong
# Processing Record 45 of Set 2 | korla
# Processing Record 46 of Set 2 | kapaa
# Processing Record 47 of Set 2 | pringsewu
# Processing Record 48 of Set 2 | pisco
# Processing Record 49 of Set 2 | jamestown
# Processing Record 50 of Set 2 | kendari
# Processing Record 1 of Set 3 | zambezi
# Processing Record 2 of Set 3 | atuona
# Processing Record 3 of Set 3 | karachi
# Processing Record 4 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 3 | sencha
# Processing Record 6 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 3 | victoria
# Processing Record 8 of Set 3 | panzhihua
# Processing Record 9 of Set 3 | naze
# Processing Record 10 of Set 3 | coihaique
# Processing Record 11 of Set 3 | nanortalik
# Processing Record 12 of Set 3 | ostrovnoy
# Processing Record 13 of Set 3 | vila franca do campo
# Processing Record 14 of Set 3 | kirakira
# Processing Record 15 of Set 3 | raga
# Processing Record 16 of Set 3 | te anau
# Processing Record 17 of Set 3 | hithadhoo
# Processing Record 18 of Set 3 | eydhafushi
# Processing Record 19 of Set 3 | butaritari
# Processing Record 20 of Set 3 | yenagoa
# Processing Record 21 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 3 | mahebourg
# Processing Record 23 of Set 3 | new norfolk
# Processing Record 24 of Set 3 | olafsvik
# Processing Record 25 of Set 3 | namikupa
# Processing Record 26 of Set 3 | dois corregos
# Processing Record 27 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 3 | manuk mangkaw
# Processing Record 29 of Set 3 | ballina
# Processing Record 30 of Set 3 | cabo san lucas
# Processing Record 31 of Set 3 | san patricio
# Processing Record 32 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 3 | abhar
# Processing Record 34 of Set 3 | bengkulu
# Processing Record 35 of Set 3 | cap malheureux
# Processing Record 36 of Set 3 | tuatapere
# Processing Record 37 of Set 3 | saint-gaudens
# Processing Record 38 of Set 3 | hede
# Processing Record 39 of Set 3 | padang
# Processing Record 40 of Set 3 | lorengau
# Processing Record 41 of Set 3 | kapit
# Processing Record 42 of Set 3 | atambua
# Processing Record 43 of Set 3 | hervey bay
# Processing Record 44 of Set 3 | norman wells
# Processing Record 45 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 46 of Set 3 | zhanakorgan
# Processing Record 47 of Set 3 | codrington
# Processing Record 48 of Set 3 | avarua
# Processing Record 49 of Set 3 | tazmalt
# Processing Record 50 of Set 3 | myaundzha
# Processing Record 1 of Set 4 | oktyabrskiy
# Processing Record 2 of Set 4 | lebanon
# Processing Record 3 of Set 4 | provideniya
# Processing Record 4 of Set 4 | westport
# Processing Record 5 of Set 4 | sambava
# Processing Record 6 of Set 4 | sitka
# Processing Record 7 of Set 4 | mogadishu
# Processing Record 8 of Set 4 | zhezkazgan
# Processing Record 9 of Set 4 | vestmannaeyjar
# Processing Record 10 of Set 4 | mlonggo
# Processing Record 11 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 12 of Set 4 | felidhoo
# City not found. Skipping...
# Processing Record 13 of Set 4 | kahului
# Processing Record 14 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 15 of Set 4 | namsos
# Processing Record 16 of Set 4 | palafrugell
# Processing Record 17 of Set 4 | salinopolis
# Processing Record 18 of Set 4 | pokosnoye
# Processing Record 19 of Set 4 | bathsheba
# Processing Record 20 of Set 4 | pangnirtung
# Processing Record 21 of Set 4 | stornoway
# Processing Record 22 of Set 4 | ucluelet
# Processing Record 23 of Set 4 | pontes e lacerda
# Processing Record 24 of Set 4 | lerwick
# Processing Record 25 of Set 4 | batagay
# Processing Record 26 of Set 4 | dayong
# Processing Record 27 of Set 4 | lagos
# Processing Record 28 of Set 4 | warrnambool
# Processing Record 29 of Set 4 | dikson
# Processing Record 30 of Set 4 | tooele
# Processing Record 31 of Set 4 | angren
# Processing Record 32 of Set 4 | moiyabana
# City not found. Skipping...
# Processing Record 33 of Set 4 | poum
# Processing Record 34 of Set 4 | college
# Processing Record 35 of Set 4 | geraldton
# Processing Record 36 of Set 4 | clyde river
# Processing Record 37 of Set 4 | chapais
# Processing Record 38 of Set 4 | zeerust
# Processing Record 39 of Set 4 | hasaki
# Processing Record 40 of Set 4 | fortuna
# Processing Record 41 of Set 4 | ribeira grande
# Processing Record 42 of Set 4 | hualmay
# Processing Record 43 of Set 4 | waipawa
# Processing Record 44 of Set 4 | dois vizinhos
# Processing Record 45 of Set 4 | shimoda
# Processing Record 46 of Set 4 | lubango
# Processing Record 47 of Set 4 | yulara
# Processing Record 48 of Set 4 | thompson
# Processing Record 49 of Set 4 | ahipara
# Processing Record 50 of Set 4 | khandyga
# Processing Record 1 of Set 5 | qasigiannguit
# Processing Record 2 of Set 5 | roald
# Processing Record 3 of Set 5 | sadovoye
# Processing Record 4 of Set 5 | lata
# Processing Record 5 of Set 5 | guerrero negro
# Processing Record 6 of Set 5 | sisimiut
# Processing Record 7 of Set 5 | lavrentiya
# Processing Record 8 of Set 5 | mar del plata
# Processing Record 9 of Set 5 | spencer
# Processing Record 10 of Set 5 | areka
# Processing Record 11 of Set 5 | sucua
# Processing Record 12 of Set 5 | saga
# Processing Record 13 of Set 5 | cidreira
# Processing Record 14 of Set 5 | cururupu
# Processing Record 15 of Set 5 | broome
# Processing Record 16 of Set 5 | bonavista
# Processing Record 17 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 18 of Set 5 | salalah
# Processing Record 19 of Set 5 | pacific grove
# Processing Record 20 of Set 5 | ternate
# Processing Record 21 of Set 5 | yumen
# Processing Record 22 of Set 5 | srednebelaya
# Processing Record 23 of Set 5 | beloha
# Processing Record 24 of Set 5 | dunedin
# Processing Record 25 of Set 5 | ilulissat
# Processing Record 26 of Set 5 | gisborne
# Processing Record 27 of Set 5 | iqaluit
# Processing Record 28 of Set 5 | chuy
# Processing Record 29 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 5 | lebu
# Processing Record 31 of Set 5 | matara
# Processing Record 32 of Set 5 | mount isa
# Processing Record 33 of Set 5 | weiser
# Processing Record 34 of Set 5 | zavodoukovsk
# Processing Record 35 of Set 5 | saldanha
# Processing Record 36 of Set 5 | sao gabriel da cachoeira
# Processing Record 37 of Set 5 | porto velho
# Processing Record 38 of Set 5 | kavaratti
# Processing Record 39 of Set 5 | carnarvon
# Processing Record 40 of Set 5 | husavik
# Processing Record 41 of Set 5 | lock haven
# Processing Record 42 of Set 5 | southbridge
# Processing Record 43 of Set 5 | longyearbyen
# Processing Record 44 of Set 5 | dakar
# Processing Record 45 of Set 5 | gamba
# Processing Record 46 of Set 5 | baishishan
# Processing Record 47 of Set 5 | hasanabad
# Processing Record 48 of Set 5 | souillac
# Processing Record 49 of Set 5 | jiaonan
# Processing Record 50 of Set 5 | atar
# Processing Record 1 of Set 6 | orgun
# City not found. Skipping...
# Processing Record 2 of Set 6 | palmer
# Processing Record 3 of Set 6 | mount gambier
# Processing Record 4 of Set 6 | goderich
# Processing Record 5 of Set 6 | sola
# Processing Record 6 of Set 6 | aksu
# Processing Record 7 of Set 6 | rocha
# Processing Record 8 of Set 6 | msanga
# Processing Record 9 of Set 6 | rio gallegos
# Processing Record 10 of Set 6 | manta
# Processing Record 11 of Set 6 | ewa beach
# Processing Record 12 of Set 6 | sorland
# Processing Record 13 of Set 6 | oktyabrskoye
# Processing Record 14 of Set 6 | vysokogornyy
# Processing Record 15 of Set 6 | foam lake
# Processing Record 16 of Set 6 | grajau
# Processing Record 17 of Set 6 | sao felix do xingu
# Processing Record 18 of Set 6 | fort nelson
# Processing Record 19 of Set 6 | esperance
# Processing Record 20 of Set 6 | port augusta
# Processing Record 21 of Set 6 | alghero
# Processing Record 22 of Set 6 | nanchang
# Processing Record 23 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 24 of Set 6 | kaeo
# Processing Record 25 of Set 6 | zhangye
# Processing Record 26 of Set 6 | luganville
# Processing Record 27 of Set 6 | bilma
# Processing Record 28 of Set 6 | nabire
# Processing Record 29 of Set 6 | faanui
# Processing Record 30 of Set 6 | cedar city
# Processing Record 31 of Set 6 | manokwari
# Processing Record 32 of Set 6 | mutis
# Processing Record 33 of Set 6 | comodoro rivadavia
# Processing Record 34 of Set 6 | neyshabur
# Processing Record 35 of Set 6 | adrar
# Processing Record 36 of Set 6 | sinnamary
# Processing Record 37 of Set 6 | ust-tsilma
# Processing Record 38 of Set 6 | oxapampa
# Processing Record 39 of Set 6 | arman
# Processing Record 40 of Set 6 | cabimas
# Processing Record 41 of Set 6 | wenling
# Processing Record 42 of Set 6 | tasiilaq
# Processing Record 43 of Set 6 | eslamshahr
# Processing Record 44 of Set 6 | calama
# Processing Record 45 of Set 6 | tapes
# Processing Record 46 of Set 6 | guarapari
# Processing Record 47 of Set 6 | turayf
# Processing Record 48 of Set 6 | hofn
# Processing Record 49 of Set 6 | ferrol
# Processing Record 50 of Set 6 | bereda
# Processing Record 1 of Set 7 | sabha
# Processing Record 2 of Set 7 | paris
# Processing Record 3 of Set 7 | naftah
# City not found. Skipping...
# Processing Record 4 of Set 7 | mana
# Processing Record 5 of Set 7 | araguacu
# Processing Record 6 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 7 of Set 7 | bairiki
# Processing Record 8 of Set 7 | barranca
# Processing Record 9 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 7 | parana
# Processing Record 11 of Set 7 | pingliang
# Processing Record 12 of Set 7 | phek
# Processing Record 13 of Set 7 | saint anthony
# Processing Record 14 of Set 7 | severo-kurilsk
# Processing Record 15 of Set 7 | lundazi
# Processing Record 16 of Set 7 | alikovo
# Processing Record 17 of Set 7 | bambous virieux
# Processing Record 18 of Set 7 | ontario
# Processing Record 19 of Set 7 | vostok
# Processing Record 20 of Set 7 | berlevag
# Processing Record 21 of Set 7 | victoria point
# Processing Record 22 of Set 7 | lisakovsk
# Processing Record 23 of Set 7 | palmas
# Processing Record 24 of Set 7 | villa rica
# Processing Record 25 of Set 7 | diffa
# Processing Record 26 of Set 7 | acari
# Processing Record 27 of Set 7 | searcy
# Processing Record 28 of Set 7 | ixtapa
# Processing Record 29 of Set 7 | mahibadhoo
# Processing Record 30 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 7 | brae
# Processing Record 32 of Set 7 | sur
# Processing Record 33 of Set 7 | lushunkou
# City not found. Skipping...
# Processing Record 34 of Set 7 | fairbanks
# Processing Record 35 of Set 7 | rudnichnyy
# Processing Record 36 of Set 7 | daugavpils
# Processing Record 37 of Set 7 | shkotovo-26
# City not found. Skipping...
# Processing Record 38 of Set 7 | hambantota
# Processing Record 39 of Set 7 | lufilufi
# Processing Record 40 of Set 7 | zhuanghe
# Processing Record 41 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 42 of Set 7 | moindou
# Processing Record 43 of Set 7 | la ronge
# Processing Record 44 of Set 7 | sao domingos
# Processing Record 45 of Set 7 | bolshaya murta
# City not found. Skipping...
# Processing Record 46 of Set 7 | billings
# Processing Record 47 of Set 7 | aberystwyth
# Processing Record 48 of Set 7 | kamenka
# Processing Record 49 of Set 7 | victor harbor
# Processing Record 50 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 8 | margate
# Processing Record 2 of Set 8 | dagua
# Processing Record 3 of Set 8 | bokspits
# City not found. Skipping...
# Processing Record 4 of Set 8 | san julian
# Processing Record 5 of Set 8 | egvekinot
# Processing Record 6 of Set 8 | keningau
# Processing Record 7 of Set 8 | mtwara
# Processing Record 8 of Set 8 | takoradi
# Processing Record 9 of Set 8 | dingle
# Processing Record 10 of Set 8 | sakakah
# Processing Record 11 of Set 8 | toora-khem
# Processing Record 12 of Set 8 | kulhudhuffushi
# Processing Record 13 of Set 8 | miguel alves
# Processing Record 14 of Set 8 | ponta do sol
# Processing Record 15 of Set 8 | warrington
# Processing Record 16 of Set 8 | port lincoln
# Processing Record 17 of Set 8 | fengxian
# Processing Record 18 of Set 8 | tura
# Processing Record 19 of Set 8 | borogontsy
# Processing Record 20 of Set 8 | mabaruma
# Processing Record 21 of Set 8 | semnan
# Processing Record 22 of Set 8 | narsaq
# Processing Record 23 of Set 8 | poso
# Processing Record 24 of Set 8 | marsh harbour
# Processing Record 25 of Set 8 | saint simons
# Processing Record 26 of Set 8 | osakarovka
# Processing Record 27 of Set 8 | murray bridge
# Processing Record 28 of Set 8 | butembo
# Processing Record 29 of Set 8 | port blair
# Processing Record 30 of Set 8 | hornepayne
# Processing Record 31 of Set 8 | kvarkeno
# Processing Record 32 of Set 8 | san quintin
# Processing Record 33 of Set 8 | hohhot
# Processing Record 34 of Set 8 | nanakuli
# Processing Record 35 of Set 8 | carutapera
# Processing Record 36 of Set 8 | talara
# Processing Record 37 of Set 8 | nyuksenitsa
# Processing Record 38 of Set 8 | visavadar
# Processing Record 39 of Set 8 | murchison
# Processing Record 40 of Set 8 | mackay
# Processing Record 41 of Set 8 | tostamaa
# City not found. Skipping...
# Processing Record 42 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 43 of Set 8 | bukachacha
# Processing Record 44 of Set 8 | los llanos de aridane
# Processing Record 45 of Set 8 | olga
# Processing Record 46 of Set 8 | saint-augustin
# Processing Record 47 of Set 8 | makaleng
# Processing Record 48 of Set 8 | waitara
# Processing Record 49 of Set 8 | necochea
# Processing Record 50 of Set 8 | kankakee
# Processing Record 1 of Set 9 | kutum
# Processing Record 2 of Set 9 | the valley
# Processing Record 3 of Set 9 | crotone
# Processing Record 4 of Set 9 | urengoy
# Processing Record 5 of Set 9 | talnakh
# Processing Record 6 of Set 9 | yerofey pavlovich
# Processing Record 7 of Set 9 | pimentel
# Processing Record 8 of Set 9 | myitkyina
# Processing Record 9 of Set 9 | nyimba
# Processing Record 10 of Set 9 | kollumerland
# City not found. Skipping...
# Processing Record 11 of Set 9 | sinnai
# Processing Record 12 of Set 9 | rae bareli
# Processing Record 13 of Set 9 | muros
# Processing Record 14 of Set 9 | koumac
# Processing Record 15 of Set 9 | koungheul
# Processing Record 16 of Set 9 | saint george
# Processing Record 17 of Set 9 | bar harbor
# Processing Record 18 of Set 9 | taoudenni
# Processing Record 19 of Set 9 | ihosy
# Processing Record 20 of Set 9 | kizukuri
# Processing Record 21 of Set 9 | svetlogorsk
# Processing Record 22 of Set 9 | chany
# Processing Record 23 of Set 9 | huazhou
# Processing Record 24 of Set 9 | half moon bay
# Processing Record 25 of Set 9 | haines junction
# Processing Record 26 of Set 9 | kefamenanu
# Processing Record 27 of Set 9 | ancud
# Processing Record 28 of Set 9 | teya
# Processing Record 29 of Set 9 | ulaanbaatar
# Processing Record 30 of Set 9 | middlebury
# Processing Record 31 of Set 9 | kalmunai
# Processing Record 32 of Set 9 | prescot
# Processing Record 33 of Set 9 | eenhana
# Processing Record 34 of Set 9 | belgrade
# Processing Record 35 of Set 9 | srednekolymsk
# Processing Record 36 of Set 9 | sturgis
# Processing Record 37 of Set 9 | shitkino
# Processing Record 38 of Set 9 | chardara
# Processing Record 39 of Set 9 | valentin gomez farias
# Processing Record 40 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 41 of Set 9 | pochutla
# Processing Record 42 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 9 | muzhi
# Processing Record 44 of Set 9 | vila do maio
# Processing Record 45 of Set 9 | juneau
# Processing Record 46 of Set 9 | kathu
# Processing Record 47 of Set 9 | qui nhon
# Processing Record 48 of Set 9 | tiznit
# Processing Record 49 of Set 9 | eureka
# Processing Record 50 of Set 9 | nelson bay
# Processing Record 1 of Set 10 | mounana
# Processing Record 2 of Set 10 | male
# Processing Record 3 of Set 10 | jardim
# Processing Record 4 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 10 | coahuayana
# Processing Record 6 of Set 10 | broken hill
# Processing Record 7 of Set 10 | ondangwa
# Processing Record 8 of Set 10 | sorong
# Processing Record 9 of Set 10 | siemiatycze
# Processing Record 10 of Set 10 | teruel
# Processing Record 11 of Set 10 | itoman
# Processing Record 12 of Set 10 | monrovia
# Processing Record 13 of Set 10 | sept-iles
# Processing Record 14 of Set 10 | miles city
# Processing Record 15 of Set 10 | walvis bay
# Processing Record 16 of Set 10 | mujiayingzi
# Processing Record 17 of Set 10 | cayenne
# Processing Record 18 of Set 10 | caceres
# Processing Record 19 of Set 10 | wencheng
# Processing Record 20 of Set 10 | beringovskiy
# Processing Record 21 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record 22 of Set 10 | swindon
# Processing Record 23 of Set 10 | horsham
# Processing Record 24 of Set 10 | kalia
# Processing Record 25 of Set 10 | balkhash
# Processing Record 26 of Set 10 | flinders
# Processing Record 27 of Set 10 | viedma
# Processing Record 28 of Set 10 | cherskiy
# Processing Record 29 of Set 10 | prince rupert
# Processing Record 30 of Set 10 | dhidhdhoo
# Processing Record 31 of Set 10 | high level
# Processing Record 32 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 10 | kirillov
# Processing Record 34 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 10 | uhlove
# Processing Record 36 of Set 10 | mao
# Processing Record 37 of Set 10 | inhambane
# Processing Record 38 of Set 10 | kailua
# Processing Record 39 of Set 10 | aklavik
# Processing Record 40 of Set 10 | gazojak
# Processing Record 41 of Set 10 | quepos
# Processing Record 42 of Set 10 | sioux lookout
# Processing Record 43 of Set 10 | dalbandin
# Processing Record 44 of Set 10 | laguna
# Processing Record 45 of Set 10 | beira
# Processing Record 46 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 47 of Set 10 | tomatlan
# Processing Record 48 of Set 10 | trelew
# Processing Record 49 of Set 10 | general pico
# Processing Record 50 of Set 10 | miguel auza
# Processing Record 1 of Set 11 | angoche
# Processing Record 2 of Set 11 | buin
# Processing Record 3 of Set 11 | araceli
# Processing Record 4 of Set 11 | caldwell
# Processing Record 5 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 11 | ust-barguzin
# Processing Record 7 of Set 11 | portsmouth
# Processing Record 8 of Set 11 | dourados
# Processing Record 9 of Set 11 | mahon
# Processing Record 10 of Set 11 | tshikapa
# Processing Record 11 of Set 11 | auki
# Processing Record 12 of Set 11 | aden
# Processing Record 13 of Set 11 | harper
# Processing Record 14 of Set 11 | mizan teferi
# Processing Record 15 of Set 11 | hamilton
# Processing Record 16 of Set 11 | port shepstone
# Processing Record 17 of Set 11 | kirovsk
# Processing Record 18 of Set 11 | saint-andre-avellin
# Processing Record 19 of Set 11 | great yarmouth
# Processing Record 20 of Set 11 | bama
# Processing Record 21 of Set 11 | novoagansk
# Processing Record 22 of Set 11 | bilibino
# Processing Record 23 of Set 11 | impfondo
# Processing Record 24 of Set 11 | nuristan
# Processing Record 25 of Set 11 | tukrah
# Processing Record 26 of Set 11 | lazaro cardenas
# Processing Record 27 of Set 11 | panalingaan
# Processing Record 28 of Set 11 | abu samrah
# Processing Record 29 of Set 11 | kargasok
# Processing Record 30 of Set 11 | moron
# Processing Record 31 of Set 11 | findlay
# Processing Record 32 of Set 11 | rawlins
# Processing Record 33 of Set 11 | geresk
# City not found. Skipping...
# Processing Record 34 of Set 11 | taguatinga
# Processing Record 35 of Set 11 | morris
# Processing Record 36 of Set 11 | nampa
# Processing Record 37 of Set 11 | bouloupari
# Processing Record 38 of Set 11 | saint-joseph
# Processing Record 39 of Set 11 | kuching
# Processing Record 40 of Set 11 | lleida
# Processing Record 41 of Set 11 | aswan
# Processing Record 42 of Set 11 | benguela
# Processing Record 43 of Set 11 | mecca
# Processing Record 44 of Set 11 | kiunga
# Processing Record 45 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 46 of Set 11 | mayo
# Processing Record 47 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 48 of Set 11 | gizo
# Processing Record 49 of Set 11 | vardo
# Processing Record 50 of Set 11 | asosa
# Processing Record 1 of Set 12 | numan
# Processing Record 2 of Set 12 | sobolevo
# Processing Record 3 of Set 12 | dudinka
# Processing Record 4 of Set 12 | touros
# Processing Record 5 of Set 12 | mogochin
# City not found. Skipping...
# Processing Record 6 of Set 12 | nipawin
# Processing Record 7 of Set 12 | alexandria
# Processing Record 8 of Set 12 | priargunsk
# Processing Record 9 of Set 12 | olutanga
# Processing Record 10 of Set 12 | palana
# Processing Record 11 of Set 12 | constitucion
# Processing Record 12 of Set 12 | vaitape
# Processing Record 13 of Set 12 | sassandra
# Processing Record 14 of Set 12 | sao jose da coroa grande
# Processing Record 15 of Set 12 | kingston
# Processing Record 16 of Set 12 | havre-saint-pierre
# Processing Record 17 of Set 12 | santa rosa
# Processing Record 18 of Set 12 | oriximina
# Processing Record 19 of Set 12 | yaviza
# Processing Record 20 of Set 12 | hazorasp
# Processing Record 21 of Set 12 | usinsk
# Processing Record 22 of Set 12 | obluche
# City not found. Skipping...
# Processing Record 23 of Set 12 | sovetskiy
# Processing Record 24 of Set 12 | mgandu
# Processing Record 25 of Set 12 | hami
# Processing Record 26 of Set 12 | lafia
# Processing Record 27 of Set 12 | piney green
# Processing Record 28 of Set 12 | kettering
# Processing Record 29 of Set 12 | iquique
# Processing Record 30 of Set 12 | barra
# Processing Record 31 of Set 12 | lar gerd
# City not found. Skipping...
# Processing Record 32 of Set 12 | enid
# Processing Record 33 of Set 12 | pierre
# Processing Record 34 of Set 12 | somerset
# Processing Record 35 of Set 12 | jiaojiang
# Processing Record 36 of Set 12 | griffith
# Processing Record 37 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 39 of Set 12 | mosetse
# Processing Record 40 of Set 12 | ivanivka
# Processing Record 41 of Set 12 | salta
# Processing Record 42 of Set 12 | bhawanipatna
# Processing Record 43 of Set 12 | la ligua
# Processing Record 44 of Set 12 | kloulklubed
# Processing Record 45 of Set 12 | tazovskiy
# Processing Record 46 of Set 12 | paoua
# Processing Record 47 of Set 12 | mauswagon
# City not found. Skipping...
# Processing Record 48 of Set 12 | big spring
# Processing Record 49 of Set 12 | pallavaram
# Processing Record 50 of Set 12 | mangan
# Processing Record 1 of Set 13 | lucapa
# Processing Record 2 of Set 13 | okhotsk
# Processing Record 3 of Set 13 | havre
# Processing Record 4 of Set 13 | tymovskoye
# Processing Record 5 of Set 13 | labuhan
# Processing Record 6 of Set 13 | itaituba
# Processing Record 7 of Set 13 | seymchan
# Processing Record 8 of Set 13 | shestakovo
# Processing Record 9 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 10 of Set 13 | wuwei
# Processing Record 11 of Set 13 | jieshi
# Processing Record 12 of Set 13 | anadyr
# Processing Record 13 of Set 13 | kysyl-syr
# Processing Record 14 of Set 13 | bulawayo
# Processing Record 15 of Set 13 | santa cruz
# Processing Record 16 of Set 13 | teodoro sampaio
# Processing Record 17 of Set 13 | lethem
# Processing Record 18 of Set 13 | yerbogachen
# Processing Record 19 of Set 13 | rawson
# Processing Record 20 of Set 13 | canutama
# Processing Record 21 of Set 13 | tripoli
# Processing Record 22 of Set 13 | pedro ii
# Processing Record 23 of Set 13 | namatanai
# Processing Record 24 of Set 13 | moctezuma
# Processing Record 25 of Set 13 | itarema
# Processing Record 26 of Set 13 | mufulira
# Processing Record 27 of Set 13 | methven
# Processing Record 28 of Set 13 | chara
# Processing Record 29 of Set 13 | faya
# Processing Record 30 of Set 13 | sabzevar
# Processing Record 31 of Set 13 | grand-santi
# Processing Record 32 of Set 13 | west plains
# Processing Record 33 of Set 13 | bestobe
# Processing Record 34 of Set 13 | miami
# Processing Record 35 of Set 13 | kaitangata
# Processing Record 36 of Set 13 | tuyen quang
# Processing Record 37 of Set 13 | charters towers
# Processing Record 38 of Set 13 | ust-maya
# Processing Record 39 of Set 13 | gushikawa
# Processing Record 40 of Set 13 | skjervoy
# Processing Record 41 of Set 13 | cootamundra
# Processing Record 42 of Set 13 | bethanien
# Processing Record 43 of Set 13 | kiruna
# Processing Record 44 of Set 13 | paranapanema
# Processing Record 45 of Set 13 | nhulunbuy
# Processing Record 46 of Set 13 | marica
# Processing Record 47 of Set 13 | pitimbu
# Processing Record 48 of Set 13 | guiglo
# Processing Record 49 of Set 13 | lagoa
# Processing Record 50 of Set 13 | palmas bellas
# Processing Record 1 of Set 14 | port hardy
# Processing Record 2 of Set 14 | meulaboh
# Processing Record 3 of Set 14 | vanavara
# Processing Record 4 of Set 14 | beidao
# Processing Record 5 of Set 14 | tevaitoa
# Processing Record 6 of Set 14 | ngunguru
# Processing Record 7 of Set 14 | mishan
# Processing Record 8 of Set 14 | daru
# Processing Record 9 of Set 14 | bud
# Processing Record 10 of Set 14 | dong hoi
# Processing Record 11 of Set 14 | esmeraldas
# Processing Record 12 of Set 14 | rapid valley
# Processing Record 13 of Set 14 | calabozo
# Processing Record 14 of Set 14 | lakhdenpokhya
# Processing Record 15 of Set 14 | taunggyi
# Processing Record 16 of Set 14 | pitkyaranta
# Processing Record 17 of Set 14 | filingue
# Processing Record 18 of Set 14 | valparaiso
# Processing Record 19 of Set 14 | pontianak
# Processing Record 20 of Set 14 | jackson
# Processing Record 21 of Set 14 | san cristobal
# Processing Record 22 of Set 14 | gimli
# Processing Record 23 of Set 14 | clearwater
# Processing Record 24 of Set 14 | old town
# Processing Record 25 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 26 of Set 14 | palmares do sul
# Processing Record 27 of Set 14 | pervomayskoye
# Processing Record 28 of Set 14 | lakes entrance
# Processing Record 29 of Set 14 | verkhoyansk
# Processing Record 30 of Set 14 | skelleftea
# Processing Record 31 of Set 14 | conceicao do araguaia
# Processing Record 32 of Set 14 | asau
# Processing Record 33 of Set 14 | progreso
# Processing Record 34 of Set 14 | riyadh
# Processing Record 35 of Set 14 | samarai
# Processing Record 36 of Set 14 | phan thiet
# Processing Record 37 of Set 14 | konongo
# Processing Record 38 of Set 14 | waingapu
# Processing Record 39 of Set 14 | wakkanai
# Processing Record 40 of Set 14 | sibolga
# Processing Record 41 of Set 14 | ayorou
# Processing Record 42 of Set 14 | matias barbosa
# Processing Record 43 of Set 14 | iralaya
# Processing Record 44 of Set 14 | svetlyy
# Processing Record 45 of Set 14 | neuquen
# Processing Record 46 of Set 14 | raglan
# Processing Record 47 of Set 14 | sete
# Processing Record 48 of Set 14 | sault sainte marie
# Processing Record 49 of Set 14 | winfield
# Processing Record 50 of Set 14 | tiarei
# Processing Record 1 of Set 15 | harwich
# Processing Record 2 of Set 15 | montijo
# Processing Record 3 of Set 15 | mtambile
# Processing Record 4 of Set 15 | cheney
# Processing Record 5 of Set 15 | sterling
# Processing Record 6 of Set 15 | bani
# Processing Record 7 of Set 15 | brigham city
# Processing Record 8 of Set 15 | shenjiamen
# Processing Record 9 of Set 15 | campos belos
# Processing Record 10 of Set 15 | jasper
# Processing Record 11 of Set 15 | camacari
# Processing Record 12 of Set 15 | erhlin
# City not found. Skipping...
# Processing Record 13 of Set 15 | valley city
# Processing Record 14 of Set 15 | vire
# Processing Record 15 of Set 15 | paucartambo
# City not found. Skipping...
# Processing Record 16 of Set 15 | enshi
# Processing Record 17 of Set 15 | kenai
# Processing Record 18 of Set 15 | mantua
# Processing Record 19 of Set 15 | draguignan
# Processing Record 20 of Set 15 | omboue
# Processing Record 21 of Set 15 | henties bay
# Processing Record 22 of Set 15 | preobrazheniye
# Processing Record 23 of Set 15 | micheweni
# Processing Record 24 of Set 15 | paso de carrasco
# Processing Record 25 of Set 15 | kurilsk
# Processing Record 26 of Set 15 | bend
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 670

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Barrow  71.2906 -156.7887      1.42        71          40        3.44
# 1  Bredasdorp -34.5322   20.0403     61.29        77         100       16.96
# 2  Nikolskoye  59.7035   30.7861     37.29        83          17        9.91
# 3         Vao -22.6667  167.4833     71.62        85          94       24.76
# 4  Baruun-Urt  46.6806  113.2792     14.86        93         100       18.01
# 5     Rikitea -23.1203 -134.9692     73.24        62          62        5.88
# 6  Chokurdakh  70.6333  147.9167    -13.59       100          94        5.44
# 7        Hilo  19.7297 -155.0900     82.13        72          40       10.36
# 8        Jaru -10.4389  -62.4664     82.27        83          64        2.24
# 9    Ust-Nera  64.5667  143.2000    -12.75        98         100        1.74
#
#   Country Current Description
# 0      US                haze
# 1      ZA     overcast clouds
# 2      RU          few clouds
# 3      NC     overcast clouds
# 4      MN                snow
# 5      PF       broken clouds
# 6      RU     overcast clouds
# 7      US    scattered clouds
# 8      BR       broken clouds
# 9      RU     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Barrow      US  71.2906 -156.7887      1.42        71          40
# 1  Bredasdorp      ZA -34.5322   20.0403     61.29        77         100
# 2  Nikolskoye      RU  59.7035   30.7861     37.29        83          17
# 3         Vao      NC -22.6667  167.4833     71.62        85          94
# 4  Baruun-Urt      MN  46.6806  113.2792     14.86        93         100
# 5     Rikitea      PF -23.1203 -134.9692     73.24        62          62
# 6  Chokurdakh      RU  70.6333  147.9167    -13.59       100          94
# 7        Hilo      US  19.7297 -155.0900     82.13        72          40
# 8        Jaru      BR -10.4389  -62.4664     82.27        83          64
# 9    Ust-Nera      RU  64.5667  143.2000    -12.75        98         100
#
#    Wind Speed Current Description
# 0        3.44                haze
# 1       16.96     overcast clouds
# 2        9.91          few clouds
# 3       24.76     overcast clouds
# 4       18.01                snow
# 5        5.88       broken clouds
# 6        5.44     overcast clouds
# 7       10.36    scattered clouds
# 8        2.24       broken clouds
# 9        1.74     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
